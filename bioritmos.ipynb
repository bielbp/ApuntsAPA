# %%
import numpy as np
import sys
import tkinter as tk
from tkinter import ttk
import ttkbootstrap as tb
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

from datetime import datetime as dt
from datetime import timedelta
from time  import sleep

def biorritmos():
    figura = plt.figure(figsize=(8, 6))
    tb.Style.instance = None
    style = tb.Style("cyborg")
    style.configure(font=("Arial", 12, "Italic Bold"))
    win = style.master
    win.title("Vaya mierda de bioritmos")
    
    lienzo = FigureCanvasTkAgg(figure=figura, master=win).get_tk_widget()
    lienzo.pack(side=tk.LEFT)

    frameDades = tb.Frame(win, width=500)
    frameDades.pack(side=tk.RIGHT)

if __name__ == "__main__":
    biorritmos()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 28
#      25     frameDades.pack(side=tk.RIGHT)
#      27 if __name__ == "__main__":
# ---> 28     biorritmos()
#
# Cell In[6], line 17, in biorritmos()
#      15 tb.Style.instance = None
#      16 style = tb.Style("cyborg")
# ---> 17 style.configure(font=("Arial", 12, "Italic Bold"))
#      18 win = style.master
#      19 win.title("Vaya mierda de bioritmos")
#
# TypeError: Style.configure() missing 1 required positional argument: 'style'
